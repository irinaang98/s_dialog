# %% [markdown]
# # My dialog system

# %% [markdown]
# **Imports**

# %%
from google.cloud import speech #speech recognition from Google Cloud
import io #provides Python’s main facilities for dealing with various types of inputs and outputs 
import requests #uses the API to access data from the web  
import os #for interacting with the operating system - in our case, python files are used in the code 
import sounddevice as sd #for recording an audio file
import numpy as np #for working with numerical data
from scipy.io.wavfile import write #sample rate for the recorded file 
import json #for using the API as a json structure 
from gtts import gTTS #text-to-speech module
from playsound import playsound #part of the text-to-speech module (playing the converted to speech text) 
from eliza import eliza #ELIZA is an early natural language processing computer program created to demonstrate the superficiality of communication between humans and machines
from file_update_vaccinations import file_update_vaccinations #updates the data from the API - for vaccines
from file_update_recovered import file_update_recovered #updates the data from the API - for number of recovered 
import emorec #emotion recognition

# %%
#!dir

# %%
#cd..

# %% [markdown]
# **Define the parameters of the audio file that will be recorded**

# %%
sr = 16000  # Sample rate
seconds = 5  # Duration of recording
filename = 'myfile.wav'

# %% [markdown]
# **Data integretation** - two python files are used here which take and update the data of the two APIs: first one for vaccinations and second one for the number of recovered people from the previous day (the APIs are provided by Robert Koch Institut)

# %%
file_update_vaccinations()
vaccinations = open('vaccinations.json')
vaccinations = json.load(vaccinations)
# Out:
# Up To Date

# %%
vaccinations
# Out:
# {'data': {'administeredVaccinations': 95332331,
#   'vaccinated': 52010167,
#   'vaccination': {'biontech': 36010517,
#    'moderna': 4283289,
#    'astraZeneca': 9196460,
#    'janssen': 2519901},
#   'delta': 55817,
#   'quote': 0.625,
#   'secondVaccination': {'vaccinated': 45842065,
#    'vaccination': {'biontech': 35461546,
#     'moderna': 4504358,
#     'astraZeneca': 3356260,
#     'janssen': 2519901},
#    'delta': 227600,
#    'quote': 0.551},
#   'latestDailyVaccinations': {'date': '2021-08-09T00:00:00.000Z',
#    'vaccinated': 55817,
#    'firstVaccination': 55817,
#    'secondVaccination': 219941},
#   'indication': {'age': None,
#    'job': None,
#    'medical': None,
#    'nursingHome': None,
#    'secondVaccination': {'age': None,
#     'job': None,
#     'medical': None,
#     'nursingHome': None}},
#   'states': {'BW': {'name': 'Baden-WÃ¼rttemberg',
#     'administeredVaccinations': 12593218,
#     'vaccinated': 6718315,
#     'vaccination': {'biontech': 4692626,
#      'moderna': 537103,
#      'astraZeneca': 1170311,
#      'janssen': 318275},
#     'delta': 6141,
#     'quote': 0.605,
#     'secondVaccination': {'vaccinated': 6193178,
#      'vaccination': {'biontech': 4872709,
#       'moderna': 608883,
#       'astraZeneca': 393311,
#       'janssen': 318275},
#      'delta': 22617,
#      'quote': 0.5579999999999999},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'BY': {'name': 'Bayern',
#     'administeredVaccinations': 14584903,
#     'vaccinated': 7890039,
#     'vaccination': {'biontech': 5585655,
#      'moderna': 643012,
#      'astraZeneca': 1327649,
#      'janssen': 333723},
#     'delta': 7440,
#     'quote': 0.601,
#     'secondVaccination': {'vaccinated': 7028587,
#      'vaccination': {'biontech': 5436179,
#       'moderna': 711254,
#       'astraZeneca': 547431,
#       'janssen': 333723},
#      'delta': 35419,
#      'quote': 0.536},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'BE': {'name': 'Berlin',
#     'administeredVaccinations': 4179797,
#     'vaccinated': 2279764,
#     'vaccination': {'biontech': 1585968,
#      'moderna': 263312,
#      'astraZeneca': 341921,
#      'janssen': 88563},
#     'delta': 3389,
#     'quote': 0.621,
#     'secondVaccination': {'vaccinated': 1988596,
#      'vaccination': {'biontech': 1515118,
#       'moderna': 265486,
#       'astraZeneca': 119429,
#       'janssen': 88563},
#      'delta': 11638,
#      'quote': 0.542},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'BB': {'name': 'Brandenburg',
#     'administeredVaccinations': 2640501,
#     'vaccinated': 1429408,
#     'vaccination': {'biontech': 975995,
#      'moderna': 126208,
#      'astraZeneca': 249124,
#      'janssen': 78081},
#     'delta': 1801,
#     'quote': 0.5670000000000001,
#     'secondVaccination': {'vaccinated': 1289174,
#      'vaccination': {'biontech': 977640,
#       'moderna': 121982,
#       'astraZeneca': 111471,
#       'janssen': 78081},
#      'delta': 5592,
#      'quote': 0.511},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'HB': {'name': 'Bremen',
#     'administeredVaccinations': 898203,
#     'vaccinated': 488092,
#     'vaccination': {'biontech': 329653,
#      'moderna': 30161,
#      'astraZeneca': 97272,
#      'janssen': 31006},
#     'delta': 384,
#     'quote': 0.7170000000000001,
#     'secondVaccination': {'vaccinated': 441117,
#      'vaccination': {'biontech': 345560,
#       'moderna': 41843,
#       'astraZeneca': 22708,
#       'janssen': 31006},
#      'delta': 1346,
#      'quote': 0.648},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'HH': {'name': 'Hamburg',
#     'administeredVaccinations': 2128975,
#     'vaccinated': 1204585,
#     'vaccination': {'biontech': 841371,
#      'moderna': 116515,
#      'astraZeneca': 188141,
#      'janssen': 58558},
#     'delta': 3660,
#     'quote': 0.652,
#     'secondVaccination': {'vaccinated': 982948,
#      'vaccination': {'biontech': 748286,
#       'moderna': 136443,
#       'astraZeneca': 39661,
#       'janssen': 58558},
#      'delta': 9446,
#      'quote': 0.532},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'HE': {'name': 'Hessen',
#     'administeredVaccinations': 7119905,
#     'vaccinated': 3917201,
#     'vaccination': {'biontech': 2691854,
#      'moderna': 331413,
#      'astraZeneca': 716537,
#      'janssen': 177397},
#     'delta': 4601,
#     'quote': 0.623,
#     'secondVaccination': {'vaccinated': 3380101,
#      'vaccination': {'biontech': 2605113,
#       'moderna': 325281,
#       'astraZeneca': 272310,
#       'janssen': 177397},
#      'delta': 13031,
#      'quote': 0.5379999999999999},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'MV': {'name': 'Mecklenburg-Vorpommern',
#     'administeredVaccinations': 1814315,
#     'vaccinated': 975857,
#     'vaccination': {'biontech': 708413,
#      'moderna': 78336,
#      'astraZeneca': 145230,
#      'janssen': 43878},
#     'delta': 1387,
#     'quote': 0.607,
#     'secondVaccination': {'vaccinated': 882336,
#      'vaccination': {'biontech': 693432,
#       'moderna': 78452,
#       'astraZeneca': 66574,
#       'janssen': 43878},
#      'delta': 5897,
#      'quote': 0.5489999999999999},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'NI': {'name': 'Niedersachsen',
#     'administeredVaccinations': 9318256,
#     'vaccinated': 5224800,
#     'vaccination': {'biontech': 3320257,
#      'moderna': 458691,
#      'astraZeneca': 1126332,
#      'janssen': 319520},
#     'delta': 4146,
#     'quote': 0.654,
#     'secondVaccination': {'vaccinated': 4412976,
#      'vaccination': {'biontech': 3317624,
#       'moderna': 450947,
#       'astraZeneca': 324885,
#       'janssen': 319520},
#      'delta': 28085,
#      'quote': 0.552},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'NW': {'name': 'Nordrhein-Westfalen',
#     'administeredVaccinations': 21466786,
#     'vaccinated': 11835008,
#     'vaccination': {'biontech': 8191293,
#      'moderna': 764986,
#      'astraZeneca': 2270150,
#      'janssen': 608579},
#     'delta': 11771,
#     'quote': 0.659,
#     'secondVaccination': {'vaccinated': 10240357,
#      'vaccination': {'biontech': 8044621,
#       'moderna': 816934,
#       'astraZeneca': 770223,
#       'janssen': 608579},
#      'delta': 63033,
#      'quote': 0.5710000000000001},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'RP': {'name': 'Rheinland-Pfalz',
#     'administeredVaccinations': 4769330,
#     'vaccinated': 2612096,
#     'vaccination': {'biontech': 1852662,
#      'moderna': 203777,
#      'astraZeneca': 438393,
#      'janssen': 117264},
#     'delta': 3171,
#     'quote': 0.638,
#     'secondVaccination': {'vaccinated': 2274498,
#      'vaccination': {'biontech': 1771841,
#       'moderna': 207542,
#       'astraZeneca': 177851,
#       'janssen': 117264},
#      'delta': 9443,
#      'quote': 0.556},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'SL': {'name': 'Saarland',
#     'administeredVaccinations': 1233382,
#     'vaccinated': 678504,
#     'vaccination': {'biontech': 507914,
#      'moderna': 55668,
#      'astraZeneca': 82942,
#      'janssen': 31980},
#     'delta': 833,
#     'quote': 0.688,
#     'secondVaccination': {'vaccinated': 586858,
#      'vaccination': {'biontech': 481414,
#       'moderna': 45879,
#       'astraZeneca': 27585,
#       'janssen': 31980},
#      'delta': 3973,
#      'quote': 0.595},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'SN': {'name': 'Sachsen',
#     'administeredVaccinations': 4065906,
#     'vaccinated': 2154561,
#     'vaccination': {'biontech': 1574175,
#      'moderna': 195304,
#      'astraZeneca': 306095,
#      'janssen': 78987},
#     'delta': 2954,
#     'quote': 0.529,
#     'secondVaccination': {'vaccinated': 1990332,
#      'vaccination': {'biontech': 1549622,
#       'moderna': 188760,
#       'astraZeneca': 172963,
#       'janssen': 78987},
#      'delta': 5029,
#      'quote': 0.489},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'ST': {'name': 'Sachsen-Anhalt',
#     'administeredVaccinations': 2358071,
#     'vaccinated': 1273769,
#     'vaccination': {'biontech': 893080,
#      'moderna': 113119,
#      'astraZeneca': 190890,
#      'janssen': 76680},
#     'delta': 1762,
#     'quote': 0.58,
#     'secondVaccination': {'vaccinated': 1160982,
#      'vaccination': {'biontech': 879982,
#       'moderna': 119870,
#       'astraZeneca': 84450,
#       'janssen': 76680},
#      'delta': 4923,
#      'quote': 0.529},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'SH': {'name': 'Schleswig-Holstein',
#     'administeredVaccinations': 3539184,
#     'vaccinated': 1943242,
#     'vaccination': {'biontech': 1324553,
#      'moderna': 159882,
#      'astraZeneca': 357624,
#      'janssen': 101183},
#     'delta': 1495,
#     'quote': 0.669,
#     'secondVaccination': {'vaccinated': 1697125,
#      'vaccination': {'biontech': 1292599,
#       'moderna': 161437,
#       'astraZeneca': 141906,
#       'janssen': 101183},
#      'delta': 5304,
#      'quote': 0.584},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'TH': {'name': 'ThÃ¼ringen',
#     'administeredVaccinations': 2269711,
#     'vaccinated': 1199314,
#     'vaccination': {'biontech': 855952,
#      'moderna': 123999,
#      'astraZeneca': 168351,
#      'janssen': 51012},
#     'delta': 865,
#     'quote': 0.562,
#     'secondVaccination': {'vaccinated': 1121409,
#      'vaccination': {'biontech': 855924,
#       'moderna': 139517,
#       'astraZeneca': 74956,
#       'janssen': 51012},
#      'delta': 2533,
#      'quote': 0.526},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}},
#    'Bund': {'name': 'Bundesressorts',
#     'administeredVaccinations': 351888,
#     'vaccinated': 185612,
#     'vaccination': {'biontech': 79096,
#      'moderna': 81803,
#      'astraZeneca': 19498,
#      'janssen': 5215},
#     'delta': 17,
#     'quote': None,
#     'secondVaccination': {'vaccinated': 171491,
#      'vaccination': {'biontech': 73882,
#       'moderna': 83848,
#       'astraZeneca': 8546,
#       'janssen': 5215},
#      'delta': 291,
#      'quote': None},
#     'indication': {'age': None,
#      'job': None,
#      'medical': None,
#      'nursingHome': None,
#      'secondVaccination': {'age': None,
#       'job': None,
#       'medical': None,
#       'nursingHome': None}}}}},
#  'meta': {'source': 'Robert Koch-Institut',
#   'contact': 'Marlon Lueckert (m.lueckert@me.com)',
#   'info': 'https://github.com/marlon360/rki-covid-api',
#   'lastUpdate': '2021-08-10T07:41:19.000Z',
#   'lastCheckedForUpdate': '2021-08-10T20:04:16.449Z'}}

# %%
file_update_recovered()
recovered = open('recovered.json')
recovered = json.load(recovered)
# Out:
# Up To Date

# %%
recovered
# Out:
# {'data': [{'recovered': 1, 'date': '2020-01-02T00:00:00.000Z'},
#   {'recovered': 2, 'date': '2020-01-23T00:00:00.000Z'},
#   {'recovered': 2, 'date': '2020-01-28T00:00:00.000Z'},
#   {'recovered': 2, 'date': '2020-01-29T00:00:00.000Z'},
#   {'recovered': 4, 'date': '2020-01-31T00:00:00.000Z'},
#   {'recovered': 1, 'date': '2020-02-01T00:00:00.000Z'},
#   {'recovered': 1, 'date': '2020-02-03T00:00:00.000Z'},
#   {'recovered': 4, 'date': '2020-02-04T00:00:00.000Z'},
#   {'recovered': 1, 'date': '2020-02-06T00:00:00.000Z'},
#   {'recovered': 1, 'date': '2020-02-07T00:00:00.000Z'},
#   {'recovered': 2, 'date': '2020-02-11T00:00:00.000Z'},
#   {'recovered': 1, 'date': '2020-02-17T00:00:00.000Z'},
#   {'recovered': 1, 'date': '2020-02-18T00:00:00.000Z'},
#   {'recovered': 1, 'date': '2020-02-20T00:00:00.000Z'},
#   {'recovered': 1, 'date': '2020-02-24T00:00:00.000Z'},
#   {'recovered': 3, 'date': '2020-02-25T00:00:00.000Z'},
#   {'recovered': 7, 'date': '2020-02-26T00:00:00.000Z'},
#   {'recovered': 23, 'date': '2020-02-27T00:00:00.000Z'},
#   {'recovered': 47, 'date': '2020-02-28T00:00:00.000Z'},
#   {'recovered': 23, 'date': '2020-02-29T00:00:00.000Z'},
#   {'recovered': 35, 'date': '2020-03-01T00:00:00.000Z'},
#   {'recovered': 41, 'date': '2020-03-02T00:00:00.000Z'},
#   {'recovered': 84, 'date': '2020-03-03T00:00:00.000Z'},
#   {'recovered': 155, 'date': '2020-03-04T00:00:00.000Z'},
#   {'recovered': 185, 'date': '2020-03-05T00:00:00.000Z'},
#   {'recovered': 182, 'date': '2020-03-06T00:00:00.000Z'},
#   {'recovered': 138, 'date': '2020-03-07T00:00:00.000Z'},
#   {'recovered': 101, 'date': '2020-03-08T00:00:00.000Z'},
#   {'recovered': 338, 'date': '2020-03-09T00:00:00.000Z'},
#   {'recovered': 592, 'date': '2020-03-10T00:00:00.000Z'},
#   {'recovered': 745, 'date': '2020-03-11T00:00:00.000Z'},
#   {'recovered': 979, 'date': '2020-03-12T00:00:00.000Z'},
#   {'recovered': 1444, 'date': '2020-03-13T00:00:00.000Z'},
#   {'recovered': 782, 'date': '2021-07-12T00:00:00.000Z'},
#   {'recovered': 1766, 'date': '2021-07-13T00:00:00.000Z'},
#   {'recovered': 1482, 'date': '2021-07-14T00:00:00.000Z'},
#   {'recovered': 1345, 'date': '2021-07-15T00:00:00.000Z'},
#   {'recovered': 1397, 'date': '2021-07-16T00:00:00.000Z'},
#   {'recovered': 1092, 'date': '2021-07-17T00:00:00.000Z'},
#   {'recovered': 402, 'date': '2021-07-18T00:00:00.000Z'},
#   {'recovered': 1160, 'date': '2021-07-19T00:00:00.000Z'},
#   {'recovered': 1891, 'date': '2021-07-20T00:00:00.000Z'},
#   {'recovered': 1812, 'date': '2021-07-21T00:00:00.000Z'},
#   {'recovered': 1637, 'date': '2021-07-22T00:00:00.000Z'},
#   {'recovered': 1536, 'date': '2021-07-23T00:00:00.000Z'},
#   {'recovered': 1135, 'date': '2021-07-24T00:00:00.000Z'},
#   {'recovered': 436, 'date': '2021-07-25T00:00:00.000Z'},
#   {'recovered': 1199, 'date': '2021-07-26T00:00:00.000Z'},
#   {'recovered': 2216, 'date': '2021-07-27T00:00:00.000Z'},
#   {'recovered': 1412, 'date': '2021-07-28T00:00:00.000Z'},
#   {'recovered': 1109, 'date': '2021-07-29T00:00:00.000Z'},
#   {'recovered': 713, 'date': '2021-07-30T00:00:00.000Z'},
#   {'recovered': 380, 'date': '2021-07-31T00:00:00.000Z'},
#   {'recovered': 106, 'date': '2021-08-01T00:00:00.000Z'},
#   {'recovered': 227, 'date': '2021-08-02T00:00:00.000Z'},
#   {'recovered': 196, 'date': '2021-08-03T00:00:00.000Z'},
#   {'recovered': 130, 'date': '2021-08-04T00:00:00.000Z'},
#   {'recovered': 93, 'date': '2021-08-05T00:00:00.000Z'},
#   {'recovered': 56, 'date': '2021-08-06T00:00:00.000Z'},
#   {'recovered': 25, 'date': '2021-08-07T00:00:00.000Z'},
#   {'recovered': 3, 'date': '2021-08-08T00:00:00.000Z'},
#   {'recovered': 13, 'date': '2021-08-09T00:00:00.000Z'}],
#  'meta': {'source': 'Robert Koch-Institut',
#   'contact': 'Marlon Lueckert (m.lueckert@me.com)',
#   'info': 'https://github.com/marlon360/rki-covid-api',
#   'lastUpdate': '2021-08-09T00:00:00.000Z',
#   'lastCheckedForUpdate': '2021-08-10T20:00:04.568Z'}}

# %%
#print(recovered["data"][recovered_days["genesen"]]["recovered"])

# %%
#recovered["data"].index({'recovered': 3093, 'date': '2020-04-15T00:00:00.000Z'})

# %% [markdown]
# **Dictionaries** - phrases defined for extracting the keywords from the input, searching in the json data and generating the output

# %%
phrases = {'hello':'Hallo! Ich bin deine neue Freundin, das Dialogsystem! Was möchtest du wissen?', 
        'continue':'Kann ich dir weiterhelfen?', 
        'goodbye':'Vielen Dank für deinen Besuch!', 
        'done':'tschüss'}

states_d = {'schleswig':'SH', 'hamburg':'HH', 'berlin':'BE', 'bayern':'BY', 
            'niedersachsen': 'NI', 'bremen': 'HB', 
            'nordrhein':'NW', 'hessen':'HE', 'rheinland':'RP', 'baden':'BW', 
            'saarland': 'SL', 'brandenburg':'BB', 'mecklenburg':'MV', 'sachsen':'SN',
            'anhalt':'ST', 'thüringen':'TH', 'deutschland':'DE', 'hier':'DE'}
state_names = {'SH':'Schleswig-Hostein', 'HH':'Hamburg', 'BE':'Berlin', 'BY':'Bayern', 
            'NI':'Niedersachsen', 'HB':'Bremen', 
            'NW': 'Nordrhein Westfalen', 'HE':'Hessen', 'RP':'Rheinland Pfalz', 'BW':'Baden Württemberg', 
            'SL':'Saarland', 'BB':'Brandenburg', 'MV':'Mecklenburg Vorpommern', 
            'SN': 'Sachsen', 'ST':'Sachsen-Anhalt', 'TH':'Thüringen', 'DE':'Deutschland'}
vaccines_d = {'biontech':'biontech', 'biontec':'biontech', 
              'moderna':'moderna', 
              'janssen':'janssen', 'jansen':'janssen',
              'delta':'delta',
              'astraZeneca':'astraZeneca', 'astra':'astraZeneca', 'zeneca':'astraZeneca'}
    
vaccine_names = {'biontech':'Biontech', 'moderna':'Moderna', 'janssen':'Janssen', 'delta':'Delta',
              'astraZeneca':'Astra Zeneca'}

recovered_d = {'genesene': 'genesen', 'genesen': 'genesen'}

recovered_days = {'genesen': -1}

emo_dict = {'happiness':'glücklich', 'neutral': 'wie immer', 'anger': 'irritiert', 'sadness': 'traurig', 
            'fear': 'ängstlich', 'boredom':'gelangweilt', 'disgust':'angeekelt'}

# %% [markdown]
# **Record a file** - will count as input

# %%
def record_file():
    data = sd.rec(int(seconds * sr), samplerate=sr, channels=1)
    sd.wait()  # Wait until recording is finished
    # Convert `data` to 16 bit integers:
    y = (np.iinfo(np.int16).max * (data/np.abs(data).max())).astype(np.int16) 
    write(filename, sr, y)

# %% [markdown]
# **Initialise Google Cloud** - for the module speech-to-text / speech recognition; the credentials can be accessed after creating a business Google account

# %%
def init_google():
    credentials=r"C:\Users\user\s_dyalog\Google Credentials.json" 
    os.environ["GOOGLE_APPLICATION_CREDENTIALS"]=credentials

# %%
init_google()

# %% [markdown]
# **Normalize the transcribed inputs** - there should be no difference between lowercase and uppercase letters

# %%
def normalize(in_s):
    return in_s.lower()

# %% [markdown]
# **Speech recognition from Google Cloud** - the function transcribes the recorded input and returns it as text

# %%
def transcribe():
    client = speech.SpeechClient()
    with io.open(filename, "rb") as audio_file:
        content = audio_file.read()
    audio = speech.RecognitionAudio(content = content)
    config = speech.RecognitionConfig(
        encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,
        language_code="de-DE",
    )
    response = client.recognize(config=config, audio=audio)
    for result in response.results:
        for index, alternative in enumerate(result.alternatives):
            print("Transcript {}: {}".format(index, alternative.transcript))
            return alternative.transcript

# %% [markdown]
# **Text-to-speech** - the function turns the text into speech and plays it

# %%
def tts(text):
    
    language = 'de'  #language (ISO Code)

    myobj1 = gTTS(text=text, lang=language, slow=False)
    file1 = str("hello" + ".mp3") #generate speech output

    myobj1.save(file1) #save as mp3 
    
    playsound(file1,True)
    os.remove(file1) #playsound

# %% [markdown]
# **Input function** - an audio file containing natural language will be recorded, transcribed and returned as text

# %%
def speech_input():
    record_file()
    text = transcribe()
    return text

# %%
def do_input():
    return speech_input()

# %% [markdown]
# **Semantic parsing** - natural language is translated into logical expressions/meaningful representations; keywords are filtered out of the input, in our case the function checks if in the input there are words related to a type of vaccination, a state from Germany or the number of recovered people (the words have been defined in the dictionaries)

# %%
def semantic(input_s):
    semantics = {'state':'', 'vaccine':'', 'recovered':'', 'answer':0}
    for key in recovered_d.keys():
        if key in input_s:
            semantics['recovered'] = recovered_d[key]
            break
    for key in states_d.keys():
        if key in input_s:
            semantics['state'] = states_d[key]
            break
    for key in  vaccines_d.keys():
        if key in input_s:
            semantics['vaccine'] =  vaccines_d[key]
            break
    return semantics

# %% [markdown]
# **Interprete the semantic content of the input** - the function verifies if in the input it was asked for a specific type of vaccine (if not, the function returns the total number of vaccines) for a specific state (if not, the function returns the vaccine from whole Germany), for the number of recovered people from the previous day. Otherwise the function returns an empty variable

# %%
# expects semantics: semantics[0] == bundesland, semantics[1] == vaccine, semantics[2] == recovered
def data(semantics):
    s = semantics['state']
    v = semantics['vaccine']
    r = semantics['recovered']
    
    if r: #number of recovered is asked
        semantics['answer'] = recovered["data"][recovered_days[r]]["recovered"]
    else:
        if s: # state given
            if s != 'DE':
                if v: # and vaccine given
                    semantics['answer'] = vaccinations["data"]["states"][s]['vaccination'][v]
                else: # all vaccines for state
                    semantics['answer'] = vaccinations["data"]["states"][s]['vaccinated']
            else:
                if v: # and vaccine given
                    semantics['answer'] = vaccinations["data"]['vaccination'][v]
                else: # all vaccines for Germany
                    semantics['answer'] = vaccinations['data']['vaccinated']
        else: # no state
            if v: # but vaccine
                semantics['answer'] = vaccinations["data"]['vaccination'][v]
            else: # nothing given
                semantics['answer'] = None
            
    return semantics

# %%
#vaccine_names

# %% [markdown]
# **Output function** - on the basis of the interpretation done in the semantic parsing module, the function returns an answer that counts as output. If in the input has been asked for information related to corona (vaccines or number of recovered), the function will use the API from RKI for generating the output; otherwise the output will be generated with Eliza. ELIZA is an early natural language processing computer program created to demonstrate the superficiality of communication between humans and machines

# %%
def output(semantics, inputs, elz):
    ret = ''
    eliza = 0 
    s = semantics['state']
    v = semantics['vaccine']
    r = semantics['recovered']
    a = semantics['answer']
    if r: #number of recovered is asked 
        r = recovered_days[r]
        ret = 'Gestern gab es {} Genesene in Deutschland'.format(a)
    else:
        if s: # state given
            s = state_names[s]
            if v: # and vaccine given
                v = vaccine_names[v]
                ret = 'Die Impfungen für {} mit {} sind {}'.format(s, v, a)
            else: # all vaccines for state
                ret = 'Die Impfungen für {} sind {}'.format(s, a)
        else: # no state
            if v: # but vaccine
                v = vaccine_names[v]
                ret = 'Die Impfungen in Deutschland mit {} sind {}'.format(v, a)
            else:
                if r: #but recovered
                    r = recovered_days[r]
                    ret = 'Gestern gab es {} Genesene in Deutschland'.format(a)
                else: # nothing given
                    ret = elz.respond(inputs)
                    eliza = 1
    return ret, eliza

# %% [markdown]
# **Initialize ELIZA** - two files are used here: a python file with the code and a txt file with all the phrases that Eliza will return

# %%
def init_eliza():
    root = r"C:\Users\user\s_dyalog"
    elz = eliza.Eliza()
    elz.load(root+"\eliza\deutsch.txt")
    return elz

# %%
elz = init_eliza()

# %% [markdown]
# **Turns the output into speech and plays it** - the output was generated in the previous function "output" as text

# %%
def output_s(text):
    print('output: '+text)
    tts(text)

# %% [markdown]
# **Dialog manager function** - responsible for the state and flow of the conversation; all functions are connected here. The dialog system determines also the emotions of the person that records the input, with the program EmoDB

# %%
def dialogmanager(elz):
    output_s(phrases['hello']) 
    input_s = do_input()
    input_s = normalize(input_s)
    while input_s and input_s != phrases['done']:
        input_s = normalize(input_s)
        emotion = emoRec.classify(filename)[0] 
        emotion_g = emo_dict[emotion]
        if (emotion_g == 'traurig'):
            output_s('ich merke du bist '+emotion_g)
            output_s('mach dir keine Sorgen! ich bin hier, um mit dir zu reden!')
        if (emotion_g == 'glücklich'):
            output_s('ich merke du bist '+emotion_g)
            output_s('wenn du glücklich bist, dann bin ich auch glücklich!')
        if (emotion_g == 'irritiert'):
            output_s('ich merke du bist '+emotion_g)
            output_s('ich kann dir gerne ein paar Atemübungen empfehlen')
        if (emotion_g == 'gelangweilt'):
            output_s('ich merke du bist '+emotion_g)
            output_s('mach lieber einen Spaziergang! wir können uns später unterhalten!')
            break
            
        semantics = semantic(input_s)
        semantics = data(semantics)
        out_string = output(semantics, input_s, elz)[0] 
       
        output_s(out_string)
        
        if (output(semantics, input_s, elz)[1] == 0):  #the question to continue will be asked only for the corona dialog, because Eliza has its own questions
            output_s(phrases['continue']) 
        input_s = do_input()
        if (input_s):
            input_s = normalize(input_s)
        else:
            output_s(phrases['goodbye'])   
    output_s('Tschüss')

# %%
emoRec = emorec.EmoRec() #in order to determine the emotions, the dialog system uses a python file with the code

# %%
dialogmanager(elz)
# Out:
# output: Hallo! Ich bin deine neue Freundin, das Dialogsystem! Was möchtest du wissen?
# Transcript 0: wie heißt du
# output: ich merke du bist traurig
# output: mach dir keine Sorgen! ich bin hier, um mit dir zu reden!
# output: Wir reden über dich, nicht über mich.
# Transcript 0: Impfungen in Hamburg
# output: Die Impfungen für Hamburg sind 1204585
# output: Kann ich dir weiterhelfen?
# Transcript 0: Amazon in Deutschland
# output: ich merke du bist traurig
# output: mach dir keine Sorgen! ich bin hier, um mit dir zu reden!
# output: Die Impfungen für Deutschland sind 52010167
# output: Kann ich dir weiterhelfen?
# Transcript 0: Nächte Impfungen Genesende Menschen
# output: ich merke du bist irritiert
# output: ich kann dir gerne ein paar Atemübungen empfehlen
# output: Gestern gab es 13 Genesene in Deutschland
# output: Kann ich dir weiterhelfen?
# Transcript 0: sage mir bitte ein paar Atemübungen
# output: ich merke du bist glücklich
# output: wenn du glücklich bist, dann bin ich auch glücklich!
# output: Ich bin nicht sicher, ob ich dich verstanden habe.
# Transcript 0: Atemübungen ich möchte lernen
# output: ich merke du bist glücklich
# output: wenn du glücklich bist, dann bin ich auch glücklich!
# output: Was würde es dir bedeuten, wenn du diesen Wunsch realisieren würdest ?
# Transcript 0: spiele ein lied
# output: Das ist ja interessant.  Sprich bitte weiter.
# Transcript 0: ist dein Liebling
# output: ich merke du bist irritiert
# output: ich kann dir gerne ein paar Atemübungen empfehlen
# output: Warum bist du beunruhigt über mein liebling ?
# Transcript 0: ich bin nicht beunruhigen bei unruhig
# output: ich merke du bist glücklich
# output: wenn du glücklich bist, dann bin ich auch glücklich!
